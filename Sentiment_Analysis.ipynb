# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (0.22.0)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.14.6)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas) (1.11.0)
# Requirement already satisfied: tweepy in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.11.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.6.8)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy) (2.18.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.2.0)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.0.1)
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/86/9e/c53e1fc61aac5ee490a6ac5e21b1ac04e55a7c2aba647bb8411c9aadf24e/vaderSentiment-3.2.1-py2.py3-none-any.whl (125kB)
#     100% |████████████████████████████████| 133kB 3.7MB/s
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.2.1

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
#My Twitter API Authentication Variables
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Data Science', count=1000)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @NHLBI_Translate: Article addresses how #Bi...
# 1  Summer MBA/Masters Internship Mortgage Analyti...
# 2  See how #DataScience has been employed by larg...
# 3  @ProfRachelGaN absolutely brilliant performanc...
# 4  RT @Ronald_vanLoon: #DataScience and Linear Al...
# 5  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 6  RT @XbeanDS: Subscribe to my Channel, where I ...
# 7  #RT @DigitaleEthik: RT @dgarcia_eu: When we us...
# 8  RT @XbeanDS: Subscribe to my Channel, where I ...
# 9  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 2019-01-29 11:18:09

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @NHLBI_Translate: Article addresses how #Bi...
# 1   Summer MBA/Masters Internship Mortgage Analyti...
# 2   See how #DataScience has been employed by larg...
# 3   @ProfRachelGaN absolutely brilliant performanc...
# 4   RT @Ronald_vanLoon: #DataScience and Linear Al...
# 5   RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 6   RT @XbeanDS: Subscribe to my Channel, where I ...
# 7   #RT @DigitaleEthik: RT @dgarcia_eu: When we us...
# 8   RT @XbeanDS: Subscribe to my Channel, where I ...
# 9   RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 10  Hello, I have tried to donate you through Cred...
# 11  RT @StephdeSilva: @Chippasaur I don't worry ab...
# 12  Subscribe to my Channel, where I will post sev...
# 13  @crtmonitorguy @IBMDataScience @coursera @Cogn...
# 14  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 15  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 16  RT @DanRather: U.S. presidents sit at an apex ...
# 17  #DataScience and Linear Algebra Fundamentals w...
# 18          #datascience #sas https://t.co/e0OOkV3HI3
# 19  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 20  IBM, The Open Group form data scientist certif...
# 21  RT @robjhyndman: Great thread on data science,...
# 22  RT @cahulaan: Facebook is giving some power ba...
# 23  RT @Ronald_vanLoon: #DataScience and Linear Al...
# 24  @WeatherProf @MaibachEd @SarahFRobinson @Colum...
# 25  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 26  RT @BreakingBI: Want to learn more about Data ...
# 27  RT @larrykim: 📈Top AI trends \n\n🔸Machine Lear...
# 28  RT @StephdeSilva: @Chippasaur I don't worry ab...
# 29  @ProfRachelGaN @CommonsSTC And we're done. Tha...
# ..                                                ...
# 70  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 71  #datascience Grad creates social change throug...
# 72  Great thread on data science, stats, ml, and e...
# 73  RT @hadleywickham: University of Zurich is loo...
# 74  RT @OgilvyConsultUK: What's in store for Behav...
# 75  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 76  RT @dgarcia_eu: When we use Twitter, we inadve...
# 77  I ❤️ #OpenScience \nAmie - GitHub for research...
# 78  Whoever said that arts degrees were useless in...
# 79  Interesting insight from the Chief Data Scient...
# 80  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 81  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 82  Data science transformations: Learn from these...
# 83  Interactive Controls for Jupyter Notebooks – T...
# 84  #datascience Grad creates social change throug...
# 85  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 86  RT @eraser: Big Data, the Science of Learning,...
# 87  SQL for Data Science - DDL, DML, DCL and TCL\n...
# 88  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 89  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 90  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 91  Data Science &amp; Analytics Technical Lead ht...
# 92  RT @dgarcia_eu: When we use Twitter, we inadve...
# 93  RT @paulcoxon: The amazing @ProfRachelGaN is a...
# 94  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 95  @LizzieGadd So the use of Creative Commons lic...
# 96  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 97  RT @dezkyoka: Tempat belajar online:\n\n• Gene...
# 98  Join infobldrs’ 31/1 webinar w/ James Cotton t...
# 99     Data Science is just: stud can a sec jets i i.
#
#                                              polarity
# 0   {'neg': 0.177, 'neu': 0.736, 'pos': 0.087, 'co...
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3   {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'comp...
# 4   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 8   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 9   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 10  {'neg': 0.109, 'neu': 0.773, 'pos': 0.118, 'co...
# 11  {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'comp...
# 12  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 13  {'neg': 0.0, 'neu': 0.79, 'pos': 0.21, 'compou...
# 14  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 15  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 16  {'neg': 0.134, 'neu': 0.788, 'pos': 0.079, 'co...
# 17  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 18  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 19  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 20  {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'comp...
# 21  {'neg': 0.0, 'neu': 0.728, 'pos': 0.272, 'comp...
# 22  {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'comp...
# 23  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 24  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 25  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 26  {'neg': 0.0, 'neu': 0.939, 'pos': 0.061, 'comp...
# 27  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 28  {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'comp...
# 29  {'neg': 0.097, 'neu': 0.617, 'pos': 0.286, 'co...
# ..                                                ...
# 70  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 71  {'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'comp...
# 72  {'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'comp...
# 73  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 74  {'neg': 0.0, 'neu': 0.795, 'pos': 0.205, 'comp...
# 75  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 76  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 77  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 78  {'neg': 0.135, 'neu': 0.865, 'pos': 0.0, 'comp...
# 79  {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound...
# 80  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 81  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 82  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 83  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 84  {'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'comp...
# 85  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 86  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 87  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 88  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 89  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 90  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 91  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 92  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 93  {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'comp...
# 94  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 95  {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'comp...
# 96  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 97  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 98  {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'comp...
# 99  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [100 rows x 2 columns]
