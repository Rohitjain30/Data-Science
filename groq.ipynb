# %%
# !pip install groq
# Out:
# Collecting groq
#   Downloading groq-0.5.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from groq) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from groq)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from groq) (2.7.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from groq) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->groq)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.9 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->groq)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq) (2.18.2)
# Installing collected packages: h11, httpcore, httpx, groq
# Successfully installed groq-0.5.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0

# %%
from google.colab import userdata
import os
import pandas as pd
from groq import Groq

# %%
client = Groq(
    api_key=userdata.get('GROQ_API'),
)

chat_completion = client.chat.completions.create(
    top_p= 0.3,
stop= "random",
max_tokens= 120,
temperature= 0.3,

    messages=[
        {
            "role": "user",
            "content": ''' Summarize this article in 50 words:
           In granting interim bail to Delhi Chief Minister Arvind Kejriwal to campaign for elections, the Supreme Court has made an unprecedented intervention to ostensibly ensure a level playing field in elections — a move that potentially opens the door for other political detainees.

In its order Friday, a bench of Justices Sanjiv Khanna and Dipankar Datta, while granting bail to Kejriwal, underlined the significance of participatory democracy saying, “General Elections supply the vis viva (force that moves) to a democracy”.

“It is no gain saying that the General Elections to Lok Sabha is the most significant and an important event this year… Between 650-700 million voters out of an electorate of about 970 million will cast their votes to elect the government of this country for the next five years,” the bench said.
''',

        }
    ],
    model="llama3-8b-8192"
)

print(chat_completion.choices[0].message.content)
# Out:
# The Supreme Court granted interim bail to Delhi Chief Minister Arvind Kejriwal to campaign for elections, ensuring a level playing field. The court emphasized the importance of participatory democracy and the significance of the upcoming General Elections, which will elect the government for the next five years.

# %%
client = Groq(
    api_key=userdata.get('GROQ_API'),
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": ''' Summarize this article in 100 words:
           In granting interim bail to Delhi Chief Minister Arvind Kejriwal to campaign for elections, the Supreme Court has made an unprecedented intervention to ostensibly ensure a level playing field in elections — a move that potentially opens the door for other political detainees.

In its order Friday, a bench of Justices Sanjiv Khanna and Dipankar Datta, while granting bail to Kejriwal, underlined the significance of participatory democracy saying, “General Elections supply the vis viva (force that moves) to a democracy”.

“It is no gain saying that the General Elections to Lok Sabha is the most significant and an important event this year… Between 650-700 million voters out of an electorate of about 970 million will cast their votes to elect the government of this country for the next five years,” the bench said.
''',
        }
    ],
    model="llama3-70b-8192",
)

print(chat_completion.choices[0].message.content)
# Out:
# The Supreme Court of India has granted interim bail to Delhi Chief Minister Arvind Kejriwal, allowing him to campaign in upcoming elections. The court's order highlights the importance of participatory democracy, stating that general elections are a vital component of a thriving democracy. The ruling may set a precedent for other political detainees, potentially leveling the playing field in elections. The court noted that the upcoming Lok Sabha elections, in which 650-700 million voters will participate, are a critical event that will shape the country's government for the next five years.
